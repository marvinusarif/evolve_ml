# %%
from pandas import read_csv
import matplotlib.pyplot as plt
import numpy as np

from sklearn.svm import SVC
from EML_plot import plot_svc, ilustrasi_RBF
from ipywidgets import interact, fixed

df = read_csv("./data3.csv")
df.tail(15).T
# Out:
#            848      849      850      851       852     853      854      855  \
# x_1    0.61866  0.17166  0.48733  0.74078  0.081797  0.1924  0.71544  0.11636
# x_2    0.82529  0.52997  0.45877  0.67178  0.823830  0.5405  0.95877  0.48509
# Label  0.00000  1.00000  1.00000  0.00000  1.000000  1.0000  1.00000  1.00000
#
#            856      857      858      859      860      861      862
# x_1    0.64631  0.18779  0.53341  0.59101  0.19931  0.77074  0.68088
# x_2    0.79605  0.49737  0.53597  0.71857  0.65526  0.88962  0.47456
# Label  0.00000  1.00000  1.00000  0.00000  0.00000  1.00000  0.00000

# %%
X = df.drop("Label",axis=1)
y = df.Label

# %%
plt.figure(figsize=(4,4))
plt.scatter(X.x_1, X.x_2, c=y, cmap="bwr", s=5)

# %% [markdown]
# C in SVM is for regularization

# %%
model = SVC(kernel="rbf", C=1e3)
model.fit(X,y)
plot_svc(X,y,model)

# %% [markdown]
# # Kernelized SVM

# %%
ilustrasi_RBF(X,y)
interact(ilustrasi_RBF, X=fixed(X), y=fixed(y), sigma=2)
# Out:
# interactive(children=(IntSlider(value=30, description='elevation', max=90, min=-30), IntSlider(value=30, descr…
# <function EML_plot.ilustrasi_RBF(X, y, elevation=30, azimuth=30, sigma=1)>
